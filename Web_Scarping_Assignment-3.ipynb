# %% [raw]
# Q1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars.
#
# Q2. In the above question, now scrape the following details of each product listed in first 3 pages of your
# search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# importing the all required libaries

import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
import requests

from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
import time
from bs4 import BeautifulSoup
import re

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(3)
url="https://www.amazon.in/"
driver.get(url)

# %%
search_field=driver.find_element_by_id("twotabsearchtextbox")    #locating search bar
user_inp=input("Enter the product you want to search:")
search_field.send_keys(user_inp)
search_button=driver.find_element_by_id("nav-search-submit-button")
search_button.click()
# Out:
# Enter the product you want to search:guitar

# %%
#collecting all the Product URLS
urls = []
for i in range(0,2):
    Page_urls=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")#collecting urls of all the guitars
    for i in Page_urls:
        urls.append(i.get_attribute('href'))
        
    #next button 
    nxt_btn=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']") 
    url=nxt_btn.get_attribute('href')
    driver.get(url)
    time.sleep(2)

# %%
Product_name = []
Brand_name= []
Price = []
Return = []
Expected_Delivery = []
Availability = []

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
#extracting 
    #Scraping data for product name
    try:
        prod=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[1]/div/h1/span")
        Product_name.append(prod.text)
    except NoSuchElementException as e:
        Product_name.append("-")
        
        
    try:
        brand=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[3]/div/a")
        Brand_name.append(brand.text)
    except NoSuchElementException as e:
        Brand_name.append("-")
        
    try:
        pri=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[4]/div[1]/div[3]/div/div/div[1]/div/div/div[2]/div/div[1]/a/h5/div[2]/div[1]/div/span/span[2]")
        Price.append(pri.text)
    except NoSuchElementException as e:
        Price.append("-")
        
    try:
        ret=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[22]/div[2]/div/div/div/div[2]/span/div[2]/a")
        Return.append(ret.text)
    except NoSuchElementException as e:
        Return.append("-")
        
    try:
        delivary=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[4]/div[1]/div[3]/div/div/div[1]/div/div/div[2]/div/div[1]/a/h5/div[3]/div[5]/div/div/div/div/div/b")
        Expected_Delivery.append(delivary.text)
    except NoSuchElementException as e:
        Expected_Delivery.append("-")
   
    try:
        avai=driver.find_element_by_xpath("//div[@id='availability']/span")
        Availability.append(avai.text)
    except NoSuchElementException as e:
        Availability.append("-")

# %%
Guitar=pd.DataFrame({})
Guitar['Name'] = Product_name
Guitar['Brand'] = Brand_name
Guitar['Price'] = Price
Guitar['Return'] = Return
Guitar['Expected_Delivery'] = Expected_Delivery
Guitar['Availability'] = Availability
Guitar['Urls'] = urls

# %%
Guitar
# Out:
#                                                   Name  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 117  Baritone Case for Double Padded Bag/Cover/Case...
# 118  Givson Venus Special Cutaway Rosewood 41 Inch ...
# 119                                                  -
# 120                                                  -
# 121                                                  -
#
#                       Brand Price Return Expected_Delivery Availability  \
# 0                         -     -      -                 -    In stock.
# 1                         -     -      -                 -    In stock.
# 2                         -     -      -                 -    In stock.
# 3                         -     -      -                 -    In stock.
# 4                         -     -      -                 -    In stock.
# ..                      ...   ...    ...               ...          ...
# 117         Brand: Baritone     -      -                 -    In stock.
# 118  Visit the GIVSON Store     -      -                 -    In stock.
# 119                       -     -      -                 -    In stock.
# 120                       -     -      -                 -    In stock.
# 121                       -     -      -                 -    In stock.
#
#                                                   Urls
# 0    https://www.amazon.in/gp/slredirect/picassoRed...
# 1    https://www.amazon.in/gp/slredirect/picassoRed...
# 2    https://www.amazon.in/gp/slredirect/picassoRed...
# 3    https://www.amazon.in/gp/slredirect/picassoRed...
# 4    https://www.amazon.in/JUAREZ-JRZ38C-Acoustic-S...
# ..                                                 ...
# 117  https://www.amazon.in/Baritone-Bag-Bass-Guitar...
# 118  https://www.amazon.in/Givson-Ketostics-VS-RED-...
# 119  https://www.amazon.in/gp/slredirect/picassoRed...
# 120  https://www.amazon.in/gp/slredirect/picassoRed...
# 121  https://www.amazon.in/gp/slredirect/picassoRed...
#
# [122 rows x 7 columns]

# %%
Guitar.to_csv('guitars.csv')

# %%
driver.close()

# %% [raw]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
#getting the google images website
driver.get('https://images.google.com')
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("fruits")
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 10 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")


img_fruits= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_fruits.append(images.get('src'))
        except NoSuchElementException:
            img_fruits.append('-')
            
time.sleep(3)

# %%
#getting the google images website
driver.get('https://images.google.com')
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("cars")
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 100 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")


img_cars= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_cars.append(images.get('src'))
        except NoSuchElementException:
            img_cars.append('-')
            
time.sleep(5)

# %%
#getting the google images website
driver.get('https://images.google.com')
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("Machine Learning")
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 100 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")


img_ML= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_ML.append(images.get('src'))
        except NoSuchElementException:
            img_ML.append('-')
            
time.sleep(3)

# %%
#getting the google images website
driver.get('https://images.google.com') 
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("Guitar")
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 100 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")


img_guitar= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_guitar.append(images.get('src'))
        except NoSuchElementException:
            img_guitar.append('-')
            
time.sleep(3)

# %%
#getting the google images website
driver.get('https://images.google.com')
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.clear()                                               
search_bar.send_keys("Cakes")
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       
search_button.click()

# %%
#scrolling the page for fetching 100 images
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

img_pg=requests.get(driver.current_url)

BS=BeautifulSoup(img_pg.content,"html.parser")


img_cakes= []

Url=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
pg_url=[]
    
for i in Url:
    pg_url.append(i.get_attribute("src"))
    for images in BS.findAll('img'):
        try:
            img_cakes.append(images.get('src'))
        except NoSuchElementException:
            img_cakes.append('-')
            
time.sleep(3)

# %%
Google_images=pd.DataFrame({})
Google_images["10_Img_Fruits"]=img_fruits[0:10]
Google_images["10_Img_Cars"]=img_cars[0:10]
Google_images["10_Img_ML"]=img_ML[0:10]
Google_images["10_Img_Guitar"]=img_guitar[0:10]
Google_images["10_Img_Cakes"]=img_cakes[0:10]
Google_images
# Out:
#                                        10_Img_Fruits  \
# 0  /images/branding/searchlogo/1x/googlelogo_desk...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                          10_Img_Cars  \
# 0  /images/branding/searchlogo/1x/googlelogo_desk...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                            10_Img_ML  \
# 0  /images/branding/searchlogo/1x/googlelogo_desk...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                        10_Img_Guitar  \
# 0  /images/branding/searchlogo/1x/googlelogo_desk...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                         10_Img_Cakes
# 0  /images/branding/searchlogo/1x/googlelogo_desk...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...

# %% [raw]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV

# %%
# Importing all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests

from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
import time
from bs4 import BeautifulSoup
import re

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
url="https://www.flipkart.com/"   #"url"
driver.get(url)
time.sleep(2)
search_bar=driver.find_element_by_xpath("//input[@class='_3704LK']")   
search_keyword=input("Type the key word: ")                
time.sleep(1)
search_bar.send_keys(search_keyword)
# Out:
# Type the key word: smartphone

# %%
driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()

# %%
page1_urls = []
urls = driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')
for url in urls:
    page1_urls.append(url.get_attribute("href"))
    time.sleep(2)

# %%
Smartphones = {}
Smartphones["Brand"] = []
Smartphones["Phone name"] = []
Smartphones["Colour"] = []
Smartphones["RAM"] = []
Smartphones["Storage(ROM)"] = []
Smartphones["Primary Camera"] = []
Smartphones["Secondary Camera"] = []
Smartphones["Display Size"] = []
Smartphones["Battery Capacity"] = []
Smartphones["Price"] = []
Smartphones["URL"] = []

# %%
# Scraping data from each url of page 1
for url in page1_urls:
    driver.get(url)                                                        
    print("Scraping URL = ", url)
    Smartphones['URL'].append(url)                                                          
    time.sleep(2)
    
    
    #Clicking on read more button
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
    
    
    #Scraping brand name of phone data
    try:
        brand_tags = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      
        Smartphones["Brand"].append(brand_tags.text.split()[0])
    except NoSuchElementException:
        Smartphones['Brand'].append('-')
    
    
    try:
        name_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')     
        Smartphones['Phone name'].append(name_tags.text)
    except NoSuchElementException:
        Smartphones['Phone name'].append('-')
  #Scraping phone color data
    try:
        color_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      
        Smartphones['Colour'].append(color_tags.text)
    except NoSuchElementException:
        Smartphones['Colour'].append('-')
     
    
    #Scraping RAM data
    try:
        ram_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                
        Smartphones['RAM'].append(ram_tags.text)
    except NoSuchElementException:
        Smartphones['RAM'].append('-')
    
    
    #Scraping ROM data
    try:
        rom_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')        
        Smartphones['Storage(ROM)'].append(rom_tags.text)
    except NoSuchElementException:
        Smartphones['Storage(ROM)'].append('-')
        
        
    #Scraping Primary camera data
    try:                                                                                    
        pri_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')
        Smartphones['Primary Camera'].append(pri_tags.text)
    except NoSuchElementException:
        Smartphones['Primary Camera'].append('-')

 #Scraping secondary camera data
    try:                                                                                    
        sec_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
        if sec_tags != "Secondary Camera" : 
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
                sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
        Smartphones['Secondary Camera'].append(sec_cam.text)
    except NoSuchElementException:
        Smartphones['Secondary Camera'].append('-')
        
        
    #Scraping Display size data 
    try:
        disp_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
        if disp_tags.text != "Display Features" : raise NoSuchElementException
        disp_size = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  
        Smartphones['Display Size'].append(disp_size.text)
    except NoSuchElementException:
        Smartphones['Display Size'].append('-')
        
#Scraping battery capacity data
    try:
        if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')              
        Smartphones['Battery Capacity'].append(bat_capa.text)
    except NoSuchElementException:
        Smartphones['Battery Capacity'].append('-')
        
    #Scraping Price data
    try:
        price_tags = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')      
        Smartphones['Price'].append(price_tags.text)
    except NoSuchElementException:
        Smartphones['Price'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/infinix-hot-12-play-racing-black-64-gb/p/itmd9c1091d0a662?pid=MOBGE2KYNTFHTXUW&lid=LSTMOBGE2KYNTFHTXUWDFJ0XM&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGE2KYNTFHTXUW.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/infinix-hot-12-play-daylight-green-64-gb/p/itmd9c1091d0a662?pid=MOBGE2KY6JUTSNCP&lid=LSTMOBGE2KY6JUTSNCPGWOMYY&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGE2KY6JUTSNCP.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/infinix-hot-12-play-horizon-blue-64-gb/p/itmd9c1091d0a662?pid=MOBGE2KYCFZA7BRB&lid=LSTMOBGE2KYCFZA7BRBUNTJVL&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGE2KYCFZA7BRB.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/infinix-note-12-turbo-force-black-128-gb/p/itmeb0ceec27e1a8?pid=MOBGE5X38FCZEZCP&lid=LSTMOBGE5X38FCZEZCPUIVB0R&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=en_BU9aIkcYybgaerDscLAAINKj9GFkLZlmizP5qKhJdvSmZO7nhLckibeqBOI%2FCkjCmZsWDdrTubGbFOlF6tHc%2BQ%3D%3D&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c31-dark-green-32-gb/p/itme0f2960da9bbb?pid=MOBGCGVAXYT3EGYR&lid=LSTMOBGCGVAXYT3EGYRW8CSTQ&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGCGVAXYT3EGYR.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c31-light-silver-32-gb/p/itme0f2960da9bbb?pid=MOBGCGVA3DANQNQH&lid=LSTMOBGCGVA3DANQNQHPKNMV9&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGCGVA3DANQNQH.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/poco-c31-royal-blue-64-gb/p/itm19effae969b86?pid=MOBG73E7GKQK4KZP&lid=LSTMOBG73E7GKQK4KZPR5ICMK&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBG73E7GKQK4KZP.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=en_BU9aIkcYybgaerDscLAAINKj9GFkLZlmizP5qKhJdvSozlBQgefp8xXTky5LzjvC3KH6Dz%2BZaKBHGgkhHnqTzQ%3D%3D&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c31-dark-green-64-gb/p/itme0f2960da9bbb?pid=MOBGCGVAZXRCZJNE&lid=LSTMOBGCGVAZXRCZJNEAEVV0M&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGCGVAZXRCZJNE.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c31-light-silver-64-gb/p/itme0f2960da9bbb?pid=MOBGCGVAGUHQ9HNJ&lid=LSTMOBGCGVAGUHQ9HNJSTKURO&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGCGVAGUHQ9HNJ.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c11-2021-cool-blue-32-gb/p/itmbd856acb97c38?pid=MOBG4BEG3HG78BDG&lid=LSTMOBG4BEG3HG78BDGUWZNDV&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBG4BEG3HG78BDG.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/infinix-zero-5g-skylight-orange-128-gb/p/itm7b2c8e6ae692b?pid=MOBGBFEZB6HFCMRZ&lid=LSTMOBGBFEZB6HFCMRZYJSZFM&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=en_BU9aIkcYybgaerDscLAAINKj9GFkLZlmizP5qKhJdvTqJbU%2BV%2Bi7z%2B75tBfXtUufPnKHVg49pIK7FoC0X5ufaQ%3D%3D&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c11-2021-cool-grey-32-gb/p/itmbd856acb97c38?pid=MOBG4BEGX8QYNKGZ&lid=LSTMOBG4BEGX8QYNKGZ8JGQTA&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBG4BEGX8QYNKGZ.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/redmi-note-10t-5g-metallic-blue-64-gb/p/itm7a558068a9f23?pid=MOBGC7QFTGDSWQZN&lid=LSTMOBGC7QFTGDSWQZNQOXYJA&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGC7QFTGDSWQZN.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c35-glowing-green-64-gb/p/itmafb045222b2cf?pid=MOBGBTHFSKHF8RAU&lid=LSTMOBGBTHFSKHF8RAUQONXWY&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGBTHFSKHF8RAU.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c11-2021-cool-blue-64-gb/p/itmbd856acb97c38?pid=MOBG5BCDBHPYMT5B&lid=LSTMOBG5BCDBHPYMT5B9SEYIT&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBG5BCDBHPYMT5B.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c11-2021-cool-grey-64-gb/p/itmbd856acb97c38?pid=MOBG5BCDJ68N57TH&lid=LSTMOBG5BCDJ68N57THYT3XBW&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBG5BCDJ68N57TH.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/motorola-e40-carbon-gray-64-gb/p/itm0ca635007c9e2?pid=MOBG2EMWUMUFGSZE&lid=LSTMOBG2EMWUMUFGSZE5BRN80&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBG2EMWUMUFGSZE.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/redmi-note-10t-5g-mint-green-64-gb/p/itm66267253b4a39?pid=MOBGC7QFNGX5K3RE&lid=LSTMOBGC7QFNGX5K3REIVGTIP&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGC7QFNGX5K3RE.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/redmi-note-10t-5g-graphite-black-64-gb/p/itmf94ef48e3c622?pid=MOBGC7QFUMCGQSS8&lid=LSTMOBGC7QFUMCGQSS8XSHYCW&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGC7QFUMCGQSS8.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/redmi-note-10t-5g-chromium-white-64-gb/p/itm6fcb4fcb76fb4?pid=MOBGC7QFEXHCY6NH&lid=LSTMOBGC7QFEXHCY6NHMP7RMC&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGC7QFEXHCY6NH.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/poco-m3-pro-5g-yellow-128-gb/p/itm023855e180d52?pid=MOBG3P55YEAPRX4Q&lid=LSTMOBG3P55YEAPRX4QAVUREF&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBG3P55YEAPRX4Q.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/realme-c35-glowing-black-64-gb/p/itmafb045222b2cf?pid=MOBGBTHFDQXQEGNS&lid=LSTMOBGBTHFDQXQEGNSZWXHXJ&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGBTHFDQXQEGNS.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021
# Scraping URL =  https://www.flipkart.com/redmi-10-midnight-black-64-gb/p/itmd93641e4ebb47?pid=MOBGC9GYEBH3GZ4E&lid=LSTMOBGC9GYEBH3GZ4EOWOH9V&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=a546a80e-40f4-4834-90bd-8f5a7a12f47f.MOBGC9GYEBH3GZ4E.SEARCH&ppt=hp&ppn=homepage&ssid=043o8sgwnk0000001654196579479&qH=1036ba3c4ed2c021

# %%
df = pd.DataFrame.from_dict(Smartphones)
df
# Out:
#        Brand     Phone name           Colour   RAM Storage(ROM)  \
# 0    Infinix    HOT 12 Play     Racing Black  4 GB        64 GB
# 1    Infinix    HOT 12 Play   Daylight Green  4 GB        64 GB
# 2    Infinix    HOT 12 Play     Horizon Blue  4 GB        64 GB
# 3    Infinix  Note 12 TURBO      Force Black  8 GB       128 GB
# 4     realme            C31       Dark Green  3 GB        32 GB
# 5     realme            C31     Light Silver  3 GB        32 GB
# 6       POCO            C31       Royal Blue  4 GB        64 GB
# 7    Infinix        Smart 6    Starry Purple  2 GB        64 GB
# 8     realme            C31       Dark Green  4 GB        64 GB
# 9     realme            C31     Light Silver  4 GB        64 GB
# 10    realme       C11 2021        Cool Blue  2 GB        32 GB
# 11   Infinix        Zero 5G  Skylight Orange  8 GB       128 GB
# 12    realme       C11 2021        Cool Grey  2 GB        32 GB
# 13     REDMI    Note 10T 5G    Metallic Blue  4 GB        64 GB
# 14    realme            C35    Glowing Green  4 GB        64 GB
# 15    realme       C11 2021        Cool Blue  4 GB        64 GB
# 16    realme       C11 2021        Cool Grey  4 GB        64 GB
# 17  MOTOROLA            e40      Carbon Gray  4 GB        64 GB
# 18     REDMI    Note 10T 5G       Mint Green  4 GB        64 GB
# 19     REDMI    Note 10T 5G   Graphite Black  4 GB        64 GB
# 20     REDMI    Note 10T 5G   Chromium White  4 GB        64 GB
# 21      POCO      M3 Pro 5G           Yellow  6 GB       128 GB
# 22    realme            C35    Glowing Black  4 GB        64 GB
# 23     REDMI             10   Midnight Black  4 GB        64 GB
#
#                                        Primary Camera   Secondary Camera  \
# 0                                   13MP + Depth Lens   8MP Front Camera
# 1                                   13MP + Depth Lens   8MP Front Camera
# 2                                   13MP + Depth Lens   8MP Front Camera
# 3                   50 MP + 2 MP Depth Lens + AI lens  16MP Front Camera
# 4                                  13MP + 2MP + 0.3MP   5MP Front Camera
# 5                                  13MP + 2MP + 0.3MP   5MP Front Camera
# 6                                    13MP + 2MP + 2MP   5MP Front Camera
# 7                                   8 MP + Depth Lens   5MP Front Camera
# 8                                  13MP + 2MP + 0.3MP   5MP Front Camera
# 9                                  13MP + 2MP + 0.3MP   5MP Front Camera
# 10                                    8MP Rear Camera   5MP Front Camera
# 11      48 MP + 13 MP Portrait Lens + 2 MP Bokeh Lens                  -
# 12                                    8MP Rear Camera   5MP Front Camera
# 13  48MP Primary Camera + 2MP Macro Lens + 2MP Dep...                  -
# 14                                 50MP + 2MP + 0.3MP   8MP Front Camera
# 15                                    8MP Rear Camera   5MP Front Camera
# 16                                    8MP Rear Camera   5MP Front Camera
# 17                                   48MP + 2MP + 2MP   8MP Front Camera
# 18  48MP Primary Camera + 2MP Macro Lens + 2MP Dep...                  -
# 19  48MP Primary Camera + 2MP Macro Lens + 2MP Dep...                  -
# 20  48MP Primary Camera + 2MP Macro Lens + 2MP Dep...                  -
# 21                                   48MP + 2MP + 2MP   8MP Front Camera
# 22                                 50MP + 2MP + 0.3MP   8MP Front Camera
# 23                                         50MP + 2MP                  -
#
#             Display Size Battery Capacity    Price  \
# 0   17.32 cm (6.82 inch)         6000 mAh   ₹8,499
# 1   17.32 cm (6.82 inch)         6000 mAh   ₹8,499
# 2   17.32 cm (6.82 inch)         6000 mAh   ₹8,499
# 3    17.02 cm (6.7 inch)         5000 mAh  ₹14,999
# 4   16.56 cm (6.52 inch)         5000 mAh   ₹9,299
# 5   16.56 cm (6.52 inch)         5000 mAh   ₹9,299
# 6   16.59 cm (6.53 inch)         5000 mAh   ₹9,999
# 7    16.76 cm (6.6 inch)         5000 mAh   ₹7,499
# 8   16.56 cm (6.52 inch)         5000 mAh   ₹9,999
# 9   16.56 cm (6.52 inch)         5000 mAh   ₹9,999
# 10   16.51 cm (6.5 inch)         5000 mAh   ₹7,499
# 11  17.22 cm (6.78 inch)         5000 mAh  ₹17,999
# 12   16.51 cm (6.5 inch)         5000 mAh   ₹7,499
# 13  16.66 cm (6.56 inch)         5000 mAh  ₹11,999
# 14   16.76 cm (6.6 inch)         5000 mAh  ₹11,999
# 15   16.51 cm (6.5 inch)         5000 mAh   ₹8,999
# 16   16.51 cm (6.5 inch)         5000 mAh   ₹8,999
# 17   16.51 cm (6.5 inch)         5000 mAh   ₹9,999
# 18  16.66 cm (6.56 inch)         5000 mAh  ₹11,999
# 19  16.66 cm (6.56 inch)         5000 mAh  ₹11,999
# 20  16.66 cm (6.56 inch)         5000 mAh  ₹11,999
# 21   16.51 cm (6.5 inch)         5000 mAh  ₹16,509
# 22   16.76 cm (6.6 inch)         5000 mAh  ₹11,999
# 23   17.02 cm (6.7 inch)         6000 mAh  ₹10,499
#
#                                                   URL
# 0   https://www.flipkart.com/infinix-hot-12-play-r...
# 1   https://www.flipkart.com/infinix-hot-12-play-d...
# 2   https://www.flipkart.com/infinix-hot-12-play-h...
# 3   https://www.flipkart.com/infinix-note-12-turbo...
# 4   https://www.flipkart.com/realme-c31-dark-green...
# 5   https://www.flipkart.com/realme-c31-light-silv...
# 6   https://www.flipkart.com/poco-c31-royal-blue-6...
# 7   https://www.flipkart.com/infinix-smart-6-starr...
# 8   https://www.flipkart.com/realme-c31-dark-green...
# 9   https://www.flipkart.com/realme-c31-light-silv...
# 10  https://www.flipkart.com/realme-c11-2021-cool-...
# 11  https://www.flipkart.com/infinix-zero-5g-skyli...
# 12  https://www.flipkart.com/realme-c11-2021-cool-...
# 13  https://www.flipkart.com/redmi-note-10t-5g-met...
# 14  https://www.flipkart.com/realme-c35-glowing-gr...
# 15  https://www.flipkart.com/realme-c11-2021-cool-...
# 16  https://www.flipkart.com/realme-c11-2021-cool-...
# 17  https://www.flipkart.com/motorola-e40-carbon-g...
# 18  https://www.flipkart.com/redmi-note-10t-5g-min...
# 19  https://www.flipkart.com/redmi-note-10t-5g-gra...
# 20  https://www.flipkart.com/redmi-note-10t-5g-chr...
# 21  https://www.flipkart.com/poco-m3-pro-5g-yellow...
# 22  https://www.flipkart.com/realme-c35-glowing-bl...
# 23  https://www.flipkart.com/redmi-10-midnight-bla...

# %%
df.to_csv('smartphone.csv')

# %% [raw]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

# %%
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)

# %%
city = input('Enter City name that has to be searched : ')
search_bar = driver.find_element_by_id("searchboxinput")                       
search_bar.clear()                                                             
time.sleep(2)
search_bar.send_keys(city)                                                     
search_btn = driver.find_element_by_id("searchbox-searchbutton")              
search_btn.click()                                                             
time.sleep(5)
# Out:
# Enter City name that has to be searched : Nigadi pune

# %%
try:
    url_str = driver.current_url
    print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/Nigdi,+Pimpri-Chinchwad,+Maharashtra/@18.6495496,73.7510053,14z/data=!3m1!4b1!4m5!3m4!1s0x3bc2b9e76cf2f9bb:0x51c2a6d121bcc6c8!8m2!3d18.6491735!4d73.7706532
# Latitude = 18.6495496, Longitude = 73.7510053

# %% [raw]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
# opening google maps web page
url = "https://trak.in/"
driver.get(url)
time.sleep(2)

# %%
#Getting xpath for funding deals
fund_button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(fund_button)

# %%
#Creating empty lists
fund_deals = {}
fund_deals['Date'] = []
fund_deals['Startup Name'] = []
fund_deals['Industry OR Vertical'] = []
fund_deals['Sub-Vertical'] = []
fund_deals['Location'] = []
fund_deals['Investor'] = []
fund_deals['Investment Type'] = []
fund_deals['Amount(in USD)'] = []

# %%
#Clicking on tablepress
for i in range(54,57):
    driver.find_element_by_xpath('//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(i)).click()

    # Scraping data of Date
    date_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for date in date_tags:
        fund_deals['Date'].append(date.text)

    # Scraping data of Startup Name
    name_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for name in name_tags:
        fund_deals['Startup Name'].append(name.text)
    
    # Scraping data of Industry OR Vertical
    ind_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind_tags:
        fund_deals['Industry OR Vertical'].append(n.text)
    
    # Scraping data of Sub-Vertical
    sv_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for sv in sv_tags:
        fund_deals['Sub-Vertical'].append(sv.text)

    # Scraping data of Location
    loc_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for loc in loc_tags:
        fund_deals['Location'].append(loc.text)
    
    # Scraping data of Investor
    inv_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for inv in inv_tags:
        fund_deals['Investor'].append(inv.text)
    
      # Scraping data of Investment Type
    invt_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for invt in invt_tags:
        fund_deals['Investment Type'].append(invt.text)
    
    # Scraping data of Amount
    amt_tags = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for amt in amt_tags:
        fund_deals['Amount(in USD)'].append(amt.text)

# %%
fund_df = pd.DataFrame(fund_deals)
fund_df
# Out:
#           Date            Startup Name    Industry OR Vertical  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# 14  12/02/2021                 Grofers              E-Commerce
# 15  09/02/2021                 Nothing              Technology
# 16  09/02/2021             SplashLearn                  EdTech
# 17  04/03/2021               DealShare              E-commerce
# 18  31/03/2021                Uniphore              Technology
# 19  30/03/2021                   Dunzo              E-commerce
# 20  30/03/2021                  BYJU’S                Edu-tech
# 21  23/03/2021             SkilloVilla                Edu-tech
# 22  25/03/2021                CityMall              E-commerce
# 23  26/03/2021                   DotPe                 FinTech
#
#                                          Sub-Vertical           Location  \
# 0                                  Insurance Services          Bengaluru
# 1       Shave care, beard care, and skincare products          New Delhi
# 2   online marketplace for farm products and services              Patna
# 3                                             HR Tech             Mumbai
# 4                  AI-powered telemedicine mobile app          Bengaluru
# 5      Online learning platform for kids in class 1-5            Gurgaon
# 6                       Whole Food plant based Nashta               Pune
# 7                                          Pharmacies          Bengaluru
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                           Online shopping platform  Jaipur, Rajasthan
# 18            Conversational Service Automation (CSA)          Palo Alto
# 19                           Hyper-local delivery app          Bengaluru
# 20                                    Online tutoring          Bengaluru
# 21                Career and job-oriented upskilling.          Bengaluru
# 22       Social ecommerce and online grocery platform            Gurgaon
# 23  Commerce and payments platform to offline ente...            Gurgaon
#
#                                              Investor Investment Type  \
# 0    A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                   Reckitt Benckiser         Venture
# 2                                     Prosus Ventures        Series C
# 3                                 Salesforce Ventures            Seed
# 4                          Heritas Capital Management   Venture Round
# 5                                     Sequoia Capital    Seed Funding
# 6                               SIDBI Venture Capital          Series
# 7           Matrix Partners India, RTP Global, others            Seed
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17                                    Innoven Capital  Debt Financing
# 18                          Sorenson Capital Partners        Series D
# 19                          Krishtal Advisors Pte Ltd        Series E
# 20         MC Global Edtech, B Capital, Baron, others        Series F
# 21                              Titan Capital, others            Seed
# 22                                     Accel Partners        Series A
# 23                                               PayU        Series A
#
#    Amount(in USD)
# 0     1,80,00,000
# 1    6,172,258.50
# 2      30,000,000
# 3      15,000,000
# 4      16,000,000
# 5      15,000,000
# 6     100,000,000
# 7       4,000,000
# 8       2,500,000
# 9     250,000,000
# 10   2,747,045.20
# 11    1,50,00,000
# 12     75,000,000
# 13      4,773,958
# 14     55,000,000
# 15     15,000,000
# 16     18,000,000
# 17    250,000,000
# 18    140,000,000
# 19      8,000,000
# 20    460,000,000
# 21    300,000,000
# 22     11,000,000
# 23     27,500,000

# %%
fund_df.to_csv("Trak_in.csv")

# %%
driver.close()

# %% [raw]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
#Opening the specified url
url = "https://www.digit.in/"
driver.get(url)
time.sleep(3)

# %%
search_laptop_button = driver.find_element_by_xpath('//div[@class="search"]').click()

# %%
search_bar=driver.find_element_by_id("globalPageSearchText")     
search_bar.send_keys('top 10 gaming laptop')
search_bar.send_keys(Keys.ENTER)

# %%
top10=driver.find_element_by_id("content_top10") 
top10.click()

# %%
best_laptop=driver.find_element_by_xpath("//div[@class='searchProduct-desc']") 
best_laptop.click()

# %%
#creating empty list
Product=[]
Processor=[]
Memory=[]
OS=[]
Display=[]
Seller=[]
Price=[]
Availability=[]

# %%
#scraping all the details
Brand_tag=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in Brand_tag:
    try:
        brandtag=i.text
        Product.append(brandtag)
    except NoSuchElementException   as e:
        Product.append('-')
        
specification = driver.find_elements_by_xpath('//div[@class="Specs-Wrap"]/ul')
for details in specification:
    lap_spec= details.find_elements_by_xpath('.//div[@class="value"]')
    try:
        OS.append(lap_spec[0].text)
        Display.append(lap_spec[1].text)
        Processor.append(lap_spec[2].text)
        Memory.append(lap_spec[3].text)
    except NoSuchElementException   as e:
        OS.append('-')
        Displah.append('-')
        Processor.append('-')
        Memory.append('-')
        
seller_info= driver.find_elements_by_xpath('//td[@class="smmerchant"]')
for info in seller_info:
    try:
        Seller.append(info.text)
    except NoSuchElementException   as e:
        Seller.append('-')
    
price = driver.find_elements_by_xpath('//td[@class="smprice"]')
for prices in price:
    try:
        Price.append(prices.text)
    except NoSuchElementException   as e:
        Price.append('-') 
    
Availability_tag=driver.find_elements_by_xpath("//p[@style='margin: 0px 0 0 0;font-size: 13px;position: relative;font-weight: 400;line-height: 19px;width: 89px;']")
for i in Availability_tag:
    try:
        Availabilitytag1=i.text
        Availability.append(Availabilitytag1.replace('\n',""))
    except NoSuchElementException   as e:
        Availability.append('-')

# %%
#creating the dataset
Top_10_Gaming_Laptop=pd.DataFrame({})
Top_10_Gaming_Laptop['Product']=Product[:10]
Top_10_Gaming_Laptop['Processor']=Processor[:10]
Top_10_Gaming_Laptop['Memory']=Memory[:10]
Top_10_Gaming_Laptop['OS']=OS[:10]
Top_10_Gaming_Laptop['Display']=Display[:10]
Top_10_Gaming_Laptop['Seller']=Seller[:10]
Top_10_Gaming_Laptop['Price']=Price[:10]
Top_10_Gaming_Laptop['Availability']=Availability[:10]

# %%
Top_10_Gaming_Laptop
# Out:
#               Product                                      Processor  \
# 0        HP VICTUS 16   5TH GEN AMD RYZEN 7-5800H | 4.4GHZ PROCESSOR
# 1        HP VICTUS 16          AMD RYZEN 5-5600H | 4.2 GHZ PROCESSOR
# 2  HP PAVILION GAMING          AMD RYZEN 5 5600H | 4.2 GHZ PROCESSOR
# 3        HP VICTUS 16   5TH GEN AMD RYZEN 5-5600H | 3.3GHZ PROCESSOR
# 4    HP PAVILION AERO          AMD RYZEN 7-5800U | 4.4 GHZ PROCESSOR
# 5              HP 14S          AMD RYZEN 7-5700U | 4.3 GHZ PROCESSOR
# 6              HP 15S          AMD RYZEN 5-5500U | 4.0 GHZ PROCESSOR
# 7              HP 14S  5TH GEN AMD RYZEN 3 5300U | 3.8 GHZ PROCESSOR
# 8        HP VICTUS 16   5TH GEN AMD RYZEN 7-5800H | 4.4GHZ PROCESSOR
# 9        HP VICTUS 16          AMD RYZEN 5-5600H | 4.2 GHZ PROCESSOR
#
#                          Memory                  OS  \
# 0    1 TB SSD/16 GB DDR4 MEMORY  WINDOWS 11 HOME OS
# 1  512 GB SSD/32 GB DDR4 MEMORY  WINDOWS 11 HOME OS
# 2   512 GB SSD/8 GB DDR4 MEMORY  WINDOWS 11 HOME OS
# 3  512 GB NVME/8 GB DDR4 MEMORY  WINDOWS 10 HOME OS
# 4    1 TB SSD/16 GB DDR4 MEMORY  WINDOWS 11 HOME OS
# 5   512 GB SSD/8 GB DDR4 MEMORY  WINDOWS 10 HOME OS
# 6   512 GB SSD/8 GB DDR4 MEMORY  WINDOWS 11 HOME OS
# 7   512 GB SSD/8 GB DDR4 MEMORY  WINDOWS 11 HOME OS
# 8    1 TB SSD/16 GB DDR4 MEMORY  WINDOWS 11 HOME OS
# 9  512 GB SSD/32 GB DDR4 MEMORY  WINDOWS 11 HOME OS
#
#                        Display    Seller      Price  Availability
# 0  16.1" (2560 X 1440) DISPLAY    Amazon  ₹ 119,990     AVAILABLE
# 1  16.1" (1920 X 1080) DISPLAY    Amazon   ₹ 72,990    BUY ON EMI
# 2  15.6" (1920 X 1080) DISPLAY    Amazon   ₹ 69,990     AVAILABLE
# 3  16.1" (1920 X 1080) DISPLAY    Amazon   ₹ 61,490    BUY ON EMI
# 4  13.3" (1920 X 1200) DISPLAY    Amazon   ₹ 78,990     AVAILABLE
# 5    14" (1920 X 1080) DISPLAY  Tatacliq   ₹ 54,769    BUY ON EMI
# 6  15.6" (1920 X 1080) DISPLAY  Tatacliq   ₹ 46,883     AVAILABLE
# 7    14" (1920 X 1080) DISPLAY     Croma   ₹ 39,990    BUY ON EMI
# 8  16.1" (2560 X 1440) DISPLAY    Amazon  ₹ 119,990     AVAILABLE
# 9  16.1" (1920 X 1080) DISPLAY    Amazon   ₹ 72,990  OUT OF STOCK

# %%
Top_10_Gaming_Laptop.to_csv("Gaming_laptops.csv")

# %%
driver.close()

# %% [raw]
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# %%
url = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url)
time.sleep(3)

# %%
#clicking the explore button
button = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
button.click()
time.sleep(1)

#select billionaire  
bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
bill.click()
time.sleep(1)

#select world billionaire  
world_bill= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill.click()
time.sleep(1)

# %%
#Scraping required data from the web page
#Creating empty lists
Rank = []
Person_Name = []
total_net_worth = []
Age = []
citizenship = []
Source = []
industry = []


while(True):
    #Scraping the data of rank
    rank_tags= driver.find_elements_by_xpath("//div[@class='rank']")
    for rank in rank_tags:
        Rank.append(rank.text)
    time.sleep(1)
    
    
    #Scraping the data of names
    name_tags= driver.find_elements_by_xpath("//div[@class='personName']//div")
    for name in name_tags:
        Person_Name.append(name.text)
    time.sleep(1)
     #Scraping data of age
    age_tags= driver.find_elements_by_xpath("//div[@class='age']//div")
    for age in age_tags:
        Age.append(age.text)   
    time.sleep(1)
    
    
    #Scraping data of citizenship
    cit_tags= driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for cit in cit_tags:
        citizenship.append(cit.text)
    time.sleep(1)
    
    #Scraping data of source of income
    sour_tags= driver.find_elements_by_xpath("//div[@class='source']")
    for sour in sour_tags:
        Source.append(sour.text)    
    time.sleep(1)
    
    
    #Scraping data of Industry
    ind_tags= driver.find_elements_by_xpath("//div[@class='category']//div")
    for ind in ind_tags:
        industry.append(ind.text)
        
        
    #scraping data of net_worth of billionaire 
    net_tags= driver.find_elements_by_xpath("//div[@class='netWorth']//div[1]")
    for net in net_tags:
        total_net_worth.append(net.text)
    time.sleep(1)
    
    
    #Clicking on next button
    try:
        next_button = driver.find_element_by_xpath("//button[@class='pagination-btn pagination-btn--next ']")
        next_button.click()
    except:
        break
    #Scraping data of net worth
Net_Worth = []
for i in range(0,len(total_net_worth),2):
    Net_Worth.append(total_net_worth[i])

# %%
#Framing data
Billionaires=pd.DataFrame({})
Billionaires['Rank'] = Rank
Billionaires['Names'] = Person_Name
Billionaires['Net Worth'] = Net_Worth
Billionaires['Age'] = Age
Billionaires['Citizenship'] = citizenship
Billionaires['Source'] = Source
Billionaires['Industry'] = industry

# %%
Billionaires
# Out:
#      Rank                     Names Net Worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %%
#Saving dataset to csv
Billionaires.to_csv("Billionaries.csv")

# %%
driver.close()

# %% [raw]
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Vide

# %%
#importing necessary libraries
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import time

#Importing requests
import requests

# importing regex
import re

# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)

# %%
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

# %%
#lets click on a video
clk_video = driver.find_element_by_id("video-title-link").click()
time.sleep(8)

#Lets scroll the comments

for _ in range(1000):

    driver.execute_script("window.scrollBy(0,100)")

#fetching required data
comments = []
upvotes = []
times = []
try:
    comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
    for i in comment:
        comments.append(i.text)
except NoSuchElementException:
    comments.append('-')
time.sleep(3)

#fetching upvotes
try:
    up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
    for i in up:
        upvotes.append(i.text)
except NoSuchElementException:
    comments.append('-')
    time.sleep(3)

#fetchin time when comment was posted
try:
    tim = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
    for i in tim:
        times.append(i.text.replace('(edited)',''))
except NoSuchElementException:
    times.append('-')
time.sleep(3)

#creating dataframe
data = list(zip(comments,upvotes,times))
df = pd.DataFrame(data, columns = ["Comment","Upvotes","Published time"])

# %%
df
# Out:
#                                                Comment Upvotes Published time
# 0    more then a later, this song is still very lov...       1     2 days ago
# 1    More than a year later, this song is still ver...      54    3 weeks ago
# 2                                         My fav  song       1     5 days ago
# 3                                      Very nice song               1 day ago
# 4    When am listening this song I remember my old ...            10 days ago
# ..                                                 ...     ...            ...
# 116                                              এক্সে       2    3 weeks ago
# 117                                               Nice            2 weeks ago
# 118  जो जो मेरा मैसेज देख रहे है उनकी मां की उम्र ब...       1    2 weeks ago
# 119                                               Nice       4    1 month ago
# 120  जो जो मेरा मैसेज देख रहे है उनकी मां की उम्र ब...       1    2 weeks ago
#
# [121 rows x 3 columns]

# %%
driver.close()

# %% [raw]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
#get the web page with given url
url = "https://www.hostelworld.com/"
driver.get(url)
time.sleep(5)

# %%
search_bar = driver.find_element_by_xpath("//input[@id='location-text-input-field']")
search_bar.send_keys('London')

# %%
srch_btn = driver.find_element_by_xpath("//button[@id='search-button']").click()

# %%
driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-08-28&to=2021-08-31&guests=2&page=1")
time.sleep(3)

# %%
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

# %%
for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    #fetching hostel name
    try:
        name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
    #fetching distance from city centre
    
    try:
        dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
    #fetch privates from price
        try:
            pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
    #fetching dorms from price
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        try:
            dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
        #fetching facilities
    try:
        fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
        fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
    #lets fetch url of each hostel
    p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    #lets click on show more button for description
    try:
        driver.find_element_by_xpath("//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
     #fetching ratings
    try:
        rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
    #fetching total reviews
        
    try:
        rws = driver.find_element_by_xpath("//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
    #fetch overall review
    try:
        overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
    #fetch property description 
    try:
        disc = driver.find_element_by_xpath("//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')

# %%
London_Hostal_data=pd.DataFrame({})
London_Hostal_data['name']=hostel_name
London_Hostal_data['dist']=distance
London_Hostal_data['ratings']=rating
London_Hostal_data['Total_reviews']=reviews
London_Hostal_data['Overall_review']=over_all
London_Hostal_data['Privates_price']=pvt_prices
London_Hostal_data['Dorms_price']=dorms_price
London_Hostal_data['Facilities']=facilities
London_Hostal_data['Property_Description']=description

# %%
London_Hostal_data
# Out:
# Empty DataFrame
# Columns: [name, dist, ratings, Total_reviews, Overall_review, Privates_price, Dorms_price, Facilities, Property_Description]
# Index: []
